# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If a clock shows the time as 3:15, what is the angle between the hour and the minute hands? Provide the answer in degrees.

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# To find the angle between the hour and minute hands at 3:15, follow these steps:
#
# 1. Calculate the position of the hour hand:
#    - Each hour corresponds to 30 degrees (360 degrees / 12 hours).
#    - At 3:00, the hour hand is at \(3 \times 30 = 90\) degrees.
#    - At 3:15, the hour hand has moved further because of the 15 minutes.
#    - The hour hand moves 0.5 degrees per minute (30 degrees per hour / 60 minutes).
#    - So, in 15 minutes, it moves \(15 \times 0.5 = 7.5\) degrees.
#    - Total position = \(90 + 7.5 = 97.5\) degrees.
#
# 2. Calculate the position of the minute hand:
#    - Each minute corresponds to 6 degrees (360 degrees / 60 minutes).
#    - At 15 minutes, the minute hand is at \(15 \times 6 = 90\) degrees.
#
# 3. Find the difference between the two positions:
#    - \( |97.5 - 90| = 7.5 \) degrees.
#
# 4. The angle between the hands is 7.5 degrees (smaller angle).
#
# **Answer: 7.5 degrees**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To find the angle between the hour and minute hands at 3:15, follow these steps:
#
# 1. Calculate the position of the hour hand:
#    - Each hour corresponds to 30 degrees (360 degrees / 12 hours).
#    - At 3:00, the hour hand is at \(3 \times 30 = 90\) degrees.
#    - At 3:15, the hour hand has moved further because of the 15 minutes.
#    - The hour hand moves 0.5 degrees per minute (30 degrees per hour / 60 minutes).
#    - So, in 15 minutes, it moves \(15 \times 0.5 = 7.5\) degrees.
#    - Total position = \(90 + 7.5 = 97.5\) degrees.
#
# 2. Calculate the position of the minute hand:
#    - Each minute corresponds to 6 degrees (360 degrees / 60 minutes).
#    - At 15 minutes, the minute hand is at \(15 \times 6 = 90\) degrees.
#
# 3. Find the difference between the two positions:
#    - \( |97.5 - 90| = 7.5 \) degrees.
#
# 4. The angle between the hands is 7.5 degrees (smaller angle).
#
# **Answer: 7.5 degrees**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI oppertunity. Return only the name of the business area."}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# Healthcare

# %%
# Find Pain point in that idustry - something chalenging that might be ripe for an Agentic solution.
# Use the following prompt:
messages = [{"role": "user", "content": "Find Pain point in " + business_idea + " - something chalenging that might be ripe for an Agentic solution."}]

# Make the second Call:

response = openai.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

# Print the pain point in the industry 
pain_point = response.choices[0].message.content
print(pain_point)
# Out:
# One significant pain point in healthcare that could benefit from an agentic solution is the management of chronic conditions. Chronic diseases such as diabetes, heart disease, and hypertension require ongoing monitoring and management, which can be challenging for both patients and healthcare providers.
#
# ### Key Challenges:
#
# 1. **Data Overload**: Patients generate a significant amount of data through wearables, health apps, and medical devices. Synthesizing this information to provide actionable insights is difficult.
#
# 2. **Patient Engagement and Compliance**: Ensuring that patients stick to their treatment plans, medication schedules, and lifestyle modifications is a persistent challenge.
#
# 3. **Coordinated Care**: Often, patients with chronic conditions see multiple specialists, but there is a lack of seamless communication between providers, leading to fragmented care.
#
# 4. **Early Detection and Intervention**: Identifying exacerbations or complications early can improve outcomes, but there is a lack of tools to efficiently predict and act on these events.
#
# 5. **Personalization of Care Plans**: Each patient’s experience with a chronic illness can vary, and current one-size-fits-all models often fail to provide optimal care.
#
# ### Potential Agentic Solutions:
#
# 1. **AI-Powered Predictive Analytics**: By leveraging machine learning, healthcare systems can predict high-risk patients and potential complications, allowing for timely intervention.
#
# 2. **Personalized Virtual Health Assistant**: An intelligent agent that helps patients manage their condition by reminding them of medications, tracking their vitals, and adjusting care plans based on real-time data.
#
# 3. **Integrated Health Ecosystem**: Develop a platform that enables seamless communication and data sharing among different healthcare providers to provide coordinated and comprehensive care.
#
# 4. **Enhanced Patient Monitoring**: Use IoT devices to continuously monitor patients’ vitals and health patterns, alerting healthcare providers to any concerning changes.
#
# 5. **Behavioral Nudges and Gamification**: Implementing a system that uses behavioral science principles to keep patients engaged in their health regimes through rewards and small challenges.
#
# By addressing these challenges with technology-driven solutions, healthcare providers can improve patient outcomes, increase efficiency, and reduce the burden of chronic disease management.

# %%
from IPython.display import display, Markdown

display(Markdown(pain_point))
# Out:
# One significant pain point in healthcare that could benefit from an agentic solution is the management of chronic conditions. Chronic diseases such as diabetes, heart disease, and hypertension require ongoing monitoring and management, which can be challenging for both patients and healthcare providers.
#
# ### Key Challenges:
#
# 1. **Data Overload**: Patients generate a significant amount of data through wearables, health apps, and medical devices. Synthesizing this information to provide actionable insights is difficult.
#
# 2. **Patient Engagement and Compliance**: Ensuring that patients stick to their treatment plans, medication schedules, and lifestyle modifications is a persistent challenge.
#
# 3. **Coordinated Care**: Often, patients with chronic conditions see multiple specialists, but there is a lack of seamless communication between providers, leading to fragmented care.
#
# 4. **Early Detection and Intervention**: Identifying exacerbations or complications early can improve outcomes, but there is a lack of tools to efficiently predict and act on these events.
#
# 5. **Personalization of Care Plans**: Each patient’s experience with a chronic illness can vary, and current one-size-fits-all models often fail to provide optimal care.
#
# ### Potential Agentic Solutions:
#
# 1. **AI-Powered Predictive Analytics**: By leveraging machine learning, healthcare systems can predict high-risk patients and potential complications, allowing for timely intervention.
#
# 2. **Personalized Virtual Health Assistant**: An intelligent agent that helps patients manage their condition by reminding them of medications, tracking their vitals, and adjusting care plans based on real-time data.
#
# 3. **Integrated Health Ecosystem**: Develop a platform that enables seamless communication and data sharing among different healthcare providers to provide coordinated and comprehensive care.
#
# 4. **Enhanced Patient Monitoring**: Use IoT devices to continuously monitor patients’ vitals and health patterns, alerting healthcare providers to any concerning changes.
#
# 5. **Behavioral Nudges and Gamification**: Implementing a system that uses behavioral science principles to keep patients engaged in their health regimes through rewards and small challenges.
#
# By addressing these challenges with technology-driven solutions, healthcare providers can improve patient outcomes, increase efficiency, and reduce the burden of chronic disease management.

# %%
# Propose the business solution

messages = [{"role": "user", "content": "Propose the business solution for the pain points in the " + business_idea + " industry. The pain points are: " + pain_point + " - something chalenging that might be ripe for an Agentic solution."}]

# Generate the business solution
response = openai.chat.completions.create(model="gpt-4o", messages=messages)

# Print the business solution
display(Markdown(response.choices[0].message.content))
# Out:
# To address the significant pain points in chronic disease management within the healthcare industry, a multifaceted approach leveraging advanced technologies and tailored strategies can make a substantial impact. Here's a comprehensive business solution addressing the key challenges identified:
#
# ### Comprehensive Smart Health Management Platform
#
# **1. AI-Powered Predictive Analytics:**
#    - **Solution:** Implement a cloud-based platform utilizing AI and machine learning algorithms to synthesize patient data from wearables, health apps, and medical devices.
#    - **Value Proposition:** This module predicts high-risk periods, potential complications, and suggests timely interventions. Healthcare providers receive actionable insights and alerts that enable preemptive care measures.
#
# **2. Personalized Virtual Health Assistant:**
#    - **Solution:** Develop a personalized virtual health assistant app capable of real-time interaction with patients, offering reminders, medication tracking, and lifestyle recommendations tailored to the individual patient’s historical data and current condition.
#    - **Value Proposition:** Enhances patient engagement and compliance by providing a user-friendly interface, making ongoing management of chronic conditions less cumbersome and more effective.
#
# **3. Integrated Health Ecosystem:**
#    - **Solution:** Create a blockchain-based platform ensuring secure and seamless communication and data sharing among healthcare providers. This platform would include patient electronic health records (EHR), diagnostic results, and treatment history.
#    - **Value Proposition:** By breaking down silos between healthcare providers, patients receive more coordinated and comprehensive care, reducing redundant tests and conflicting treatments.
#
# **4. Enhanced Patient Monitoring:**
#    - **Solution:** Collaborate with IoT manufacturers to develop and distribute advanced health monitoring devices that continuously track vital signs and health patterns.
#    - **Value Proposition:** Continuous, real-time monitoring provides healthcare providers with useful data to detect any deviations from normal health patterns early, enabling faster response to adverse health events.
#
# **5. Behavioral Nudges and Gamification:**
#    - **Solution:** Integrate game-like elements and personalized behavioral nudges into the virtual health assistant to promote patient engagement. Examples include reward systems for adherence to care plans, interactive challenges, and community leaderboards.
#    - **Value Proposition:** Increases patient motivation and participation by introducing an innovative and enjoyable aspect to adhering to health regimes.
#
# ### Implementation Plan:
#
# - **Phase 1:** Develop a robust platform architecture focusing on security, scalability, and user-friendliness.
# - **Phase 2:** Integrate AI engines and establish partnerships with IoT device manufacturers for comprehensive monitoring solutions.
# - **Phase 3:** Pilot the platform with a diverse group of healthcare providers and patients, gather feedback and iterate the design.
# - **Phase 4:** Launch a comprehensive marketing and education campaign targeting healthcare providers, insurers, and patients to drive adoption.
# - **Phase 5:** Continuously update the platform with new technologies and methodologies, such as telemedicine integration and enhanced data analytics.
#
# ### Expected Outcomes:
#
# - Improved patient outcomes due to proactive management and early intervention.
# - Increased patient satisfaction and compliance with treatment plans.
# - Reduced healthcare costs through efficient resource utilization and minimized emergency interventions.
# - Enhanced collaborative environment among healthcare providers resulting in higher quality of care.
#
# By effectively addressing the identified pain points through these agentic solutions, the healthcare industry can take significant strides in transforming chronic disease management, benefiting all stakeholders involved.
